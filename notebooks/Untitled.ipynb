# %%
# Import packages.
import pandas as pd
print("Packages imported.")
# Out:
# Packages imported.

# %%
def read_csv(file):
    return pd.read_csv(file)

# %%
sellers = read_csv('../data/raw/sellers_202206221505.csv')
sellers = sellers.drop(['createdAt', 'updatedAt', 'deletedAt', 'id', 'name'], axis=1)
sellers.head(5)
# Out:
#                            email  timeOnTheMarket    companyName  \
# 0          rewal64185@azteen.com  Menos de 2 anos     Teste Tech
# 1  emanuelqalbuquerque@gmail.com  Menos de 2 anos      match<IT>
# 2           gomes.luiz@gmail.com       2 a 5 anos       ACME CO.
# 3         nem.moises97@gmail.com       2 a 5 anos  Moisés Junior
# 4    andre_nunes2005@hotmail.com  Mais de 10 anos       Nunes IT
#
#                                      serviceOffering  \
# 0        Desenvolvimento de Softwares e/ou Testes QA
# 1  Soluções de Visualização de Dados, Data Analyt...
# 2  Soluções de Visualização de Dados, Data Analyt...
# 3  Soluções de Colaboração, Produtividade e Gestã...
# 4        Desenvolvimento de Softwares e/ou Testes QA
#
#                                employeesQty qualificationSealsDescription  \
# 0  Sou empreendedor individual / Freelancer                           NaN
# 1                       2 a 10 funcionários         Solution Partner Gold
# ...

# %%
buyers = read_csv('../data/raw/buyers_202206221508.csv')
# Out:
#                   createdAt                updatedAt  deletedAt  \
# 0   2022-05-10 12:24:17.705  2022-05-10 16:41:09.573        NaN
# 1   2022-05-11 15:42:59.925  2022-05-11 15:52:21.018        NaN
# 2   2022-05-14 00:06:06.410  2022-05-19 11:57:27.760        NaN
# 3   2022-01-26 13:23:38.230  2022-02-07 14:45:52.978        NaN
# 4   2022-01-26 18:29:35.849  2022-01-26 18:46:02.089        NaN
# 5   2022-03-15 13:02:07.070  2022-03-15 13:22:56.773        NaN
# 6   2022-05-10 18:55:25.191  2022-05-10 19:42:29.764        NaN
# 7   2022-03-14 20:55:35.228  2022-05-16 15:06:28.143        NaN
# 8   2022-05-05 13:53:17.217  2022-05-05 13:57:39.655        NaN
# 9   2022-05-10 19:20:12.847  2022-05-10 19:25:57.247        NaN
# 10  2022-01-27 14:41:00.905  2022-01-27 15:12:02.414        NaN
# 11  2022-04-06 19:02:03.606  2022-05-18 19:11:14.517        NaN
# 12  2022-01-26 16:31:30.514  2022-05-22 22:11:46.675        NaN
# 13  2022-05-10 19:27:12.560  2022-05-17 13:40:39.071        NaN
# ...
